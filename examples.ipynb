# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %run -t ftc_example.py
# Out:
# IPython CPU timings (estimated):
#   User   :      17.75 s.
#   System :       0.41 s.
# Wall time:      18.20 s.

# %%
ftc.plot_contourplots()

# %%
# for i in range(1, len(ftc.time)):
#     temp = 5 + 10 * np.sin(np.pi * 2 * ftc.time[i]) + 5 * np.sin(np.pi * 2 * ftc.time[i] * 365)
#     ftc.Temperature.bc_top = temp
#     if temp < 0:
#         ftc.O2.bc_top = 0
#     else:
#         ftc.O2.bc_top = 0.231


#     ftc.integrate_one_timestep(i)
# Plotting times for presentation:
t1 = np.linspace(6,7,7)/365
t2 = np.linspace(13,14,7)/365
times = np.concatenate((t1, t2))
ftc.plot_times('Temperature', times)

# %%
z = ftc.species['O2']['rates'][:, 0:-1:100]
np.max(np.abs(z))
# Out:
# 102.60471924243531

# %%
ftc.plot_contourplots_of_rates()

# %%
ftc.plot_depths("Temperature",[0,1,3,7,10,25,40])
