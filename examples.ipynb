# %%
# %run -t ftc_example.py
# Out:
# IPython CPU timings (estimated):
#   User   :      49.43 s.
#   System :       1.30 s.
# Wall time:      51.07 s.

# %%
ftc_column.plot_contourplots()

# %%
# %matplotlib inline
