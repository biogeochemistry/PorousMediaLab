# %%
# %matplotlib inline

# %%
# %run -t ftc_example.py
# Out:
# IPython CPU timings (estimated):
#   User   :      91.31 s.
#   System :       2.31 s.
# Wall time:      94.59 s.

# %%
ftc.plot_contourplots()
