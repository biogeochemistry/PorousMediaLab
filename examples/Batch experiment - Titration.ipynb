# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../src')
from BatchLab import BatchLab
import numpy as np
# %matplotlib inline

# %%
tend = 0.04
dt = 0.0001
phi=0.5

# %%
bl = BatchLab(tend, dt)

# %%
C_init=0.001/3
bl.add_species(element='H2CO3', init_C=C_init)
bl.add_species(element='HCO3', init_C=C_init)
bl.add_species(element='CO3', init_C=C_init)

# bl.add_acid(species=['H2CO3', 'HCO3', 'CO3'], pKa=[3.6, 10.32])

# bl.add_species(element='Na', init_C=0)

# bl.add_ion(element='Na', charge=1)

# %%
# bl.constants['Ks_CaCO3'] = 8e-9
# bl.constants['Ks_CaSO4'] = 2.4e-9
# bl.constants['k_pre'] = 1e-2
# bl.constants['k_dis'] = 1e-1
# # bl.constants['CF'] = (1-phi)/phi  ### conversion factor

# %%
# bl.rates['R_pre_CaCO3'] = 'k_pre * (Ca*CO3/Ks_CaCO3-1)'
# bl.rates['R_pre_CaSO4'] = 'k_pre * (Ca*SO4/Ks_CaSO4-1)'
# bl.rates['R_dis_CaCO3'] = 'k_dis * CaCO3 * (1 - Ca*CO3/Ks_CaCO3)'
# bl.rates['R_dis_CaSO4'] = 'k_dis * CaSO4 * (1 - Ca*SO4/Ks_CaSO4)'
# # bl.rates['R_pre_CaCO3'] = 'k_pre * tanh(Ca*CO3/Ks_CaCO3-1)'
# # bl.rates['R_pre_CaSO4'] = 'k_pre * tanh(Ca*SO4/Ks_CaSO4-1)'

# %%
# bl.dcdt['CaCO3'] = 'R_pre_CaCO3 - R_dis_CaCO3'
# bl.dcdt['Ca'] = '-R_pre_CaCO3 + R_dis_CaCO3 - R_pre_CaSO4 + R_dis_CaSO4'
# bl.dcdt['CO3'] = '-R_pre_CaCO3 + R_dis_CaCO3'
# bl.dcdt['CaSO4'] = 'R_pre_CaSO4 - R_dis_CaSO4'
# bl.dcdt['Na'] = '-R_pre_CaSO4 + R_dis_CaSO4'

# %%
# %pdb

# %%
bl.solve()
# Out:
# Simulation started:
# 	 2017-09-11 18:10:38
#
#
# Estimated time of the code execution:
# 	 0h:00m:00s
# Will finish approx.:
# 	 2017-09-11 18:10:38

# %%
bl.plot_profiles()
# Out:
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plt.plot(bl.SO4['concentration'][0]*bl.Ca['concentration'][0])
plt.hlines(bl.constants['Ks_CaSO4'], 0, 500)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-987afe543cf4> in <module>()
# ----> 1 plt.plot(bl.SO4['concentration'][0]*bl.Ca['concentration'][0])
#       2 plt.hlines(bl.constants['Ks_CaSO4'], 0, 500)
#
# ~/git/biogeochemistry/PorousMedia/src/Lab.py in __getattr__(self, attr)
#      27
#      28     def __getattr__(self, attr):
# ---> 29         return self.species[attr]
#      30
#      31     def solve(self):
#
# KeyError: 'SO4'

# %%
bl.profiles

# %%
plt.plot(bl.CaCO3.rates[0])

# %%
plt.plot(bl.CO3['concentration'][0]*bl.Ca['concentration'][0])
plt.hlines(bl.constants['Ks_CaCO3'], 0, 400)

# %%
import numpy as np

# %%
a = np.linspace(1,5,5)

# %%
a[:,1]

# %%
a[]

# %%
b = np.ones((1,5))*a

# %%
b[:,1]

# %%
import numexpr as ne

# %%
ne.evaluate('2*(2+3)')

# %%
>>> from pHcalc import Acid, Neutral, System
>>> import numpy as np
>>> import matplotlib.pyplot as plt # Optional for plotting below

>>> na_moles = np.linspace(1e-8, 5.e-3, 500)
>>> sol_volume = 1. # Liter
>>> phos = Acid(pKa=[2.148, 7.198, 12.375], charge=0, conc=1.e-3)
>>> phs = []
>>> for mol in na_moles:
>>>     na = Neutral(charge=1, conc=mol/sol_volume)
>>>     system = System(phos, na)
>>>     system.pHsolve(guess_est=True)
>>>     phs.append(system.pH)
>>> plt.plot(na_moles, phs)
>>> plt.show()

# %%
[idx_j  for idx_j in range(1)]
