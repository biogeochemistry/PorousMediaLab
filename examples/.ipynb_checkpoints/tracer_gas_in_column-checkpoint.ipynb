# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../src')
from PorousMediaLab import PorousMediaLab
import numpy as np
# %matplotlib inline

# %%
t = 7*24 ## hours
dx = 0.2 ## cm
L = 40 ## cm
x = np.linspace(0, L, L / dx + 1)
phi = ( 0.98 - 0.7 ) * np.exp( -x / 20 ) + 0.7
dt = 1
# ftc = PorousMediaLab(L, dx, t, dt, phi)

# %%
plt.plot(x, phi)

# %%
ftc = PorousMediaLab(L, dx, t, dt, phi)

# %%
ftc.add_species(is_solute=True, element='SF6', D=1e-5*60*60, init_C=1, bc_top=0., bc_top_type='dirichlet', bc_bot=0, bc_bot_type='flux')

# %%
ftc.solve()
# Out:
# Simulation starts  with following params:
# 	tend = 168.0,
# 	dt = 1.00e+00,
# 	L = 40.0,
# 	dx = 2.00e-01,
# 	w = 0.00
# Simulation started:
# 	 2017-05-31 16:21:16
#
#
# Estimated time of the code execution:
# 	 0h:00m:00s
# Will finish approx.:
# 	 2017-05-31 16:21:16

# %%
ftc.plot_contourplots()

# %%
ftc.plot_profiles()

# %%
Fx = ftc.estimate_flux_at_top('SF6')
ftc.custom_plot(ftc.time, Fx)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-df6f1d60c0c1> in <module>()
#       1 Fx = ftc.estimate_flux_at_top('SF6')
# ----> 2 ftc.custom_plot(ftc.time, Fx)
#
# /Users/MarkelovIgor/git/biogeochemistry/PorousMedia/src/PorousMediaLab.py in __getattr__(self, attr)
#      66
#      67     def __getattr__(self, attr):
# ---> 68         return self.species[attr]
#      69
#      70     def add_temperature(self, init_temperature, D=281000):
#
# KeyError: 'custom_plot'

# %%
ftc.SF6
