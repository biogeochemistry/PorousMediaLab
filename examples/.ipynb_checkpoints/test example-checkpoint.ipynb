# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../src')
from PorousMediaLab import PorousMediaLab
import numpy as np
# %matplotlib inline

# %%
# tend = 10
tend = 20
dt = 0.01
dx = 0.1 
L = 10
x = np.linspace(0, L, L / dx + 1)
t = np.linspace(0, tend, round(tend / dt) + 1)
phi = ( 0.98 - 0.7 ) * np.exp( -x / 20 ) + 0.7

# %%
plt.plot(phi)

# %%
ftc = PorousMediaLab(L, dx, tend, dt, phi)

# %%
ftc.add_species(is_solute=True, element='Ca', D=4, init_C=1, bc_top=0., bc_top_type='neumann', bc_bot=0., bc_bot_type='neumann')
# ftc.add_species(is_solute=True, element='Ca', D=4, init_C=1, bc_top=1., bc_top_type='constant', bc_bot=1, bc_bot_type='constant')

# %%
# %%timeit
ftc.solve()
# Out:
# Simulation starts  with following params:
# 	tend = 20.0,
# 	dt = 1.00e-02,
# 	L = 10.0,
# 	dx = 1.00e-01,
# 	w = 0.00
# Simulation started:
# 	 2017-08-15 20:55:44
#
#
# Estimated time of the code execution:
# 	 0h:00m:00s
# Will finish approx.:
# 	 2017-08-15 20:55:45

# %%
ftc.plot_contourplots()

# %%
ftc.plot_profiles()

# %%
ftc.profiles.Ca
# Out:
# array([ 2.72083392,  2.7209715 ,  2.72136564,  2.72201713,  2.72292676,
#         2.72409531,  2.72552356,  2.72721229,  2.72916225,  2.73137422,
#         2.73384896,  2.73658721,  2.73958973,  2.74285725,  2.74639052,
#         2.75019026,  2.75425722,  2.7585921 ,  2.76319563,  2.76806851,
#         2.77321147,  2.77862519,  2.78431039,  2.79026774,  2.79649794,
#         2.80300168,  2.80977962,  2.81683244,  2.82416081,  2.83176539,
#         2.83964684,  2.84780581,  2.85624295,  2.8649589 ,  2.87395429,
#         2.88322977,  2.89278596,  2.90262348,  2.91274294,  2.92314497,
#         2.93383016,  2.94479913,  2.95605246,  2.96759076,  2.9794146 ,
#         2.99152458,  3.00392127,  3.01660524,  3.02957706,  3.04283729,
#         3.05638649,  3.07022523,  3.08435403,  3.09877345,  3.11348403,
#         3.12848629,  3.14378077,  3.159368  ,  3.17524849,  3.19142275,
#         3.20789129,  3.22465463,  3.24171325,  3.25906766,  3.27671835,
#         3.29466579,  3.31291048,  3.33145288,  3.35029347,  3.36943271,
#         3.38887107,  3.408609  ,  3.42864696,  3.44898539,  3.46962474,
#         3.49056544,  3.51180793,  3.53335264,  3.55519999,  3.5773504 ,
#         3.59980429,  3.62256206,  3.64562413,  3.6689909 ,  3.69266275,
#         3.7166401 ,  3.74092331,  3.76551279,  3.7904089 ,  3.81561202,
#         3.84112252,  3.86694077,  3.89306714,  3.91950196,  3.94624561,
#         3.97329843,  4.00066076,  4.02833295,  4.05631532,  4.08460822,
#         4.11321196])
