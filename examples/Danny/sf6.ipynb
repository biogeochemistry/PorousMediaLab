# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../..')
from PorousMediaLab import PorousMediaLab
import numpy as np
# %matplotlib inline

# %%
t = 5 * 24 * 60 * 60
dx = 0.2
L = 40
x = np.linspace(0, L, L / dx + 1)
phi = ( 0.98 - 0.7 ) * np.exp( -x / 20 ) + 0.7
dt = 60
# ftc = PorousMediaLab(L, dx, t, dt, phi)

# %%
plt.plot(x, phi)

# %%
ftc = PorousMediaLab(L, dx, t, dt, phi)

# %%
ftc.add_species(is_solute=True, element='O2', D=368, init_C=0, bc_top=0.231, bc_top_type='dirichlet', bc_bot=0, bc_bot_type='flux')
ftc.add_species(is_solute=True, element='CO2', D=320, init_C=0, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')
ftc.add_species(is_solute=True, element='Fe2', D=127, init_C=0, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')
ftc.add_solid_species('OM', init_C=15)
ftc.add_solute_species('CO2', D=320, init_C=0)
# Out:
# (201, 201)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-c86686aa53ae> in <module>()
# ----> 1 ftc.add_species(is_solute=True, element='O2', D=368, init_C=0, bc_top=0.231, bc_top_type='dirichlet', bc_bot=0, bc_bot_type='flux')
#       2 ftc.add_species(is_solute=True, element='CO2', D=320, init_C=0, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')
#       3 ftc.add_species(is_solute=True, element='Fe2', D=127, init_C=0, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')
#       4 ftc.add_solid_species('OM', init_C=15)
#       5 ftc.add_solute_species('CO2', D=320, init_C=0)
#
# /Users/MarkelovIgor/git/biogeochemistry/PorousMediaLab/PorousMediaLab.py in add_species(self, is_solute, element, D, init_C, bc_top, bc_top_type, bc_bot, bc_bot_type)
#     299         self.species[element]['concentration'][:, 0] = self.species[element]['init_C']
#     300         self.profiles[element] = self.species[element]['concentration'][:, 0]
# --> 301         self.template_AL_AR(element)
#     302         self.update_matrices_due_to_bc(element, 0)
#     303         self.dcdt[element] = '0'
#
# /Users/MarkelovIgor/git/biogeochemistry/PorousMediaLab/PorousMediaLab.py in template_AL_AR(self, element)
#     330         print((e1 * (-s / 2 - q / 4)).shape)
#     331         self.species[element]['AL'] = spdiags(np.concatenate((e1 * (-s / 2 - q / 4), e1 * (self.species[element]['theta'] + s), e1 * (-s / 2 + q / 4)),
# --> 332                                                              axis=1).T, [-1, 0, 1], self.N, self.N, format='csc')  # .toarray()
#     333         self.species[element]['AR'] = spdiags(np.concatenate((e1 * (s / 2 + q / 4), e1 * (self.species[element]['theta'] - s), e1 * (s / 2 - q / 4)),
#     334                                                              axis=1).T, [-1, 0, 1], self.N, self.N, format='csc')  # .toarray()
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/scipy/sparse/construct.py in spdiags(data, diags, m, n, format)
#      59
#      60     """
# ---> 61     return dia_matrix((data, diags), shape=(m,n)).asformat(format)
#      62
#      63
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/scipy/sparse/dia.py in __init__(self, arg1, shape, dtype, copy)
#     141             raise ValueError('number of diagonals (%d) '
#     142                     'does not match the number of offsets (%d)'
# --> 143                     % (self.data.shape[0], len(self.offsets)))
#     144
#     145         if len(np.unique(self.offsets)) != len(self.offsets):
#
# ValueError: number of diagonals (603) does not match the number of offsets (3)
