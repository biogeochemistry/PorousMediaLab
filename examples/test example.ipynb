# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../src')
from PorousMediaLab import PorousMediaLab
import numpy as np
# %matplotlib inline

# %%
# tend = 10
tend = 200
dt = 0.01
dx = 0.1 
L = 100
x = np.linspace(0, L, L / dx + 1)
t = np.linspace(0, tend, round(tend / dt) + 1)
phi = ( 0.98 - 0.7 ) * np.exp( -x / 20 ) + 0.7
phi = 1-0.00004*x**2

# %%
plt.plot(phi)

# %%
ftc = PorousMediaLab(L, dx, tend, dt, phi)

# %%
ftc.add_species(is_solute=True, element='Ca', D=1, init_C=1, bc_top=0., bc_top_type='neumann', bc_bot=0., bc_bot_type='neumann')
# ftc.add_species(is_solute=True, element='Ca', D=4, init_C=1, bc_top=1., bc_top_type='constant', bc_bot=1, bc_bot_type='constant')
# Out:
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/scipy/sparse/compressed.py:730: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)

# %%
# %%timeit
ftc.solve()
# Out:
# Simulation starts  with following params:
# 	tend = 200.0,
# 	dt = 1.00e-02,
# 	L = 100.0,
# 	dx = 1.00e-01,
# 	w = 0.00
# Simulation started:
# 	 2017-08-22 12:23:25
#
#
# Estimated time of the code execution:
# 	 0h:00m:10s
# Will finish approx.:
# 	 2017-08-22 12:23:35

# %%
ftc.plot_contourplots()

# %%
ftc.plot_profiles()

# %%
ftc.profiles.Ca
# Out:
# array([ 0.98406315,  0.98406275,  0.98406234, ...,  0.97677907,
#         0.9767794 ,  0.97677994])

# %%
ftc.rates == True
# Out:
# False

# %%
ftc.phi
# Out:
# array([ 1.       ,  0.9999996,  0.9999984, ...,  0.6015984,  0.6007996,
#         0.6      ])
