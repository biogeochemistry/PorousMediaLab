# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('../../src')
from PorousMediaLab import PorousMediaLab
import numpy as np
# %matplotlib inline

import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 32})
sns.set_context("poster", rc={"font.size":34,"axes.titlesize":34,"axes.labelsize":34, "lines.linewidth": 4, 'lines.markersize':10})  
plt.rcParams['figure.figsize'] = 15, 12

# %%
Ch = np.array([0.00252, 0.03796, 0.00240, 0.02313, 0.00269, 0.025860486, 0.00120, 0.02413, 0.00289, 0.07907, 0.00033, 0.05428,
               0.00037, 0.04148, 0.00012, 0.03243, 0.00207, 0.07155, 0.00025, 0.04486, 0.00091, 0.03825, 0.00004, 0.02900])  # umol/L
C1 = np.array([0.583805742, 0.512316043, 7.594574065, 3.692777585, 1.23916, 3.341085178, 1.150807588, 4.416529162, 2.43327421,
               1.561870655, 1.139, 2.307, 1.285, 1.645, 1.359, 2.123, 3.691, 1.127, 4.296, 3.375, 3.484, 4.625, 11.027, 8.556])  # umol/L
C2 = np.array([0.407484095, 0.310616172, 1.33571996, 0.159434741, 0.990766831, 0.824523478, 0.192815818, 2.082757337, 1.135352013,
               1.410438875, 0.618, 1.152, 0.661, 0.674, 0.869, 0.659, 22.243, 0.367, 0.624, 5.966, 5.082, 12.488, 8.330, 6.609])  # umol/L
C3 = np.array([0.005173366, 0.008733477, 0.026839503, 0.051847005, 0.062452074, 0.113866379, 0.006698022, 0.025017556, 0.111039922,
               0.107684264, 0.059, 0.095, 0.105, 0.175, 0.145, 0.177, -0.002, 0.096, 0.013, 0.535, 0.015, 0.023, 0.066, 0.045])  # umol/L
Tm = np.array([0, 2, 26, 28, 52, 54, 78, 80, 272, 274, 298, 300, 324, 326, 350, 352, 544, 546, 570, 572, 596, 598, 622, 624])  # h
zm = np.array([9, 21, 33])  # cm

D_SF6 = 0.00001028 * 60 * 60  # cm2/h
Kh = 0.0056685
Vh = 0.375518497 * 1000  # cm3
SA = 44.17864669  # cm2
Hcc = 0.0056685

# %%
tend = 80 ## hours
dt = 1
dx = 0.2 ## cm
L = 40 ## cm
x = np.linspace(0, L, L / dx + 1)
t = np.linspace(0, tend, round(tend / dt) + 1)
phi = ( 0.94 - 0.94 ) * np.exp( -x / 5 ) + 0.94
Chs = np.zeros(t.shape) #
Fx = np.zeros(t.shape)

# %%
plt.plot(x, phi)

# %%
ftc = PorousMediaLab(L, dx, tend, dt, phi)

# %%
SF6_init = np.zeros(x.size)
SF6_init[x > 0] = 0.3
SF6_init[x > 0] = 0.3
SF6_init[x > 15] = 0.4
SF6_init[x > 27] = 0.05

# %%
ftc.add_species(is_solute=True, element='SF6', D=D_SF6, init_C=SF6_init, bc_top=0., bc_top_type='dirichlet', bc_bot=0, bc_bot_type='flux')

# %%
Tm[:8]
# Out:
# array([ 0,  2, 26, 28, 52, 54, 78, 80])

# %%
for i in range(1, len(ftc.time)):
    ftc.integrate_one_timestep(i)
    Fx[i] = ftc.estimate_flux_at_top('SF6', i)
    if (ftc.time[i] > Tm[0] and ftc.time[i] < Tm[1]):
        Chs[i] = Chs[i-1] +  Fx[i] * Ahs / Vhs * dt
        ftc.SF6.bc_top = Chs[i]
    else:
        ftc.SF6.bc_top = 0
        Chs[i] = 0

# %%
F = ftc.estimate_flux_at_top('SF6') # dissolved gas flux

plt.plot(ftc.time, F/100)
plt.scatter(Tm[::2][:4]+1, dCh[:4]*Vh/SA/dT[:4])
plt.ylabel(r'Flux, $[umol/cm^2/h]$')
plt.xlabel('Time, [h]')

# %%
ftc.plot_contourplots(labels=False)

# %%
ftc.plot_profiles()

# %% [markdown]
# $${\displaystyle H^{cc}=c_{\text{a}}/c_{\text{g}}}$$

# %%
from measurements import *

# %%
plt.scatter(Tm[1::2], Ch[1::2], label='t0')
plt.scatter(Tm[::2], Ch[::2], label='t1')
plt.ylabel('Concentration in Headspace, [umol/L]')
plt.legend()

# %%
dT = Tm[1::2] - Tm[::2]
dCh = (Ch[1::2] - Ch[::2])/1000

# %%
plt.scatter(Tm[::2]+1, dCh*Vh/SA/dT)
plt.ylim([0, 0.4e-3])
plt.ylabel(r'Flux, $[umol/cm^2/h]$')
plt.xlabel('Time, [h]')

# %%
plt.plot(phi[::-1])
