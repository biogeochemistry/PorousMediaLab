# %%
import matplotlib.pyplot as plt
import sys
import math

# sys.path.append('../../')
# from column import Column

from porousmedialab.column import Column

import numpy as np

# %matplotlib inline
# %matplotlib notebook

from thawmeasurements import C3h, T1C3h, F1C3h, T2C3h, F2C3h, T3C3h, F3C3h, C3D9, T1C3D9, T2C3D9, T3C3D9, C3D21, T1C3D21, F1C3D21, T2C3D21, F2C3D21, T3C3D21, F3C3D21, C3D33, T1C3D33, F1C3D33, T2C3D33, F2C3D33, T3C3D33, F3C3D33, Tm, T1Tm, F1Tm, T2Tm, F2Tm, T3Tm, F3Tm, zm, D_SF6w, D_SF6g, Kh, phi_m, z_phi, Vh3, SA, D_column, Vi, Ci, T1Ci, F1Ci, T2Ci, F2Ci, T3Ci, F3Ci, Ti, T1Ti, F1Ti, T2Ti, F2Ti, T3Ti, F3Ti, SF6_Hcc, T_frz, T_thw

import seaborn as sns
                                                                                                                                                                                                                    
sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 32})
sns.set_context("poster", rc={"font.size":34,"axes.titlesize":34,"axes.labelsize":34, "lines.linewidth": 4, 'lines.markersize':10})  
plt.rcParams['figure.figsize'] = 8, 6

# %%
#FIRST THAW PERIOD#

# %%
tend = 132 ## hours
dt = 0.01
dx = 0.2 ## cm
L = 40 ## cm
x = np.linspace(0, L, L / dx + 1)
t = np.linspace(0, tend, round(tend / dt) + 1)

#phi = 0.8
Chs = np.zeros(t.shape) #
Fx = np.zeros(t.shape)
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   """

# %%
#Total porosity#

# phi = 0.97

phi = ( 0.99 - 0.91 ) * np.exp( -x / 10 ) + 0.91

# phi = np.array ([0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 
#       0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#       0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94,
#        0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 
#        0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#        0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91,
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95])

# %%
# plt.plot(x, phi)
# plt.plot(x, phi_1)

# %%
dT = T1Tm[1::2] - T1Tm[::2]

dC3h = (T1C3h[1::2] - T1C3h[::2])

Mi = T1Ci*Vi # mass injected

#h_inj = Vi/SA/phi
h_inj = Vi/SA/0.93
h_inj
# Out:
# 0.48678214375801243

# %%
ftc1 = Column(L, dx, tend, dt)

# %%
#wc = 0.911
#a = phi - wc


#k_in  = 0.02855
#0.013
#k_out  = k_in

# %%
#(((D_SF6g * Kh * (a**(10/3))) / (phi**2)) + ((D_SF6w * (wc**(10/3))) / (phi**2))) / (wc + (a * Kh))

# %%
#Pores from the FTR experiment#

phi_w = phi*(0.875/0.97)
phi_g = 1 - phi
#phi_g = phi*((0.97-0.875)/0.97)
#phi_p = 1 - phi
phi_p = phi*((0.97-0.875)/0.97) 

# conversion factor from water to gas
F_wg = phi_w/phi_g
# conversion factor from water to pore space
F_wp = phi_w/phi_p

# %%
ftc1.add_species(theta=(((phi_g**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6g', D= D_SF6g, init_C=0, bc_top=0, bc_top_type='constant', bc_bot=0, bc_bot_type='constant', w = -0.00)  #-0.055
ftc1.add_species(theta=(((phi_w**(10/3))/(phi**2)) / (phi_w + phi_g )), name='SF6w', D= D_SF6w, init_C=0, bc_top=0, bc_top_type='constant', bc_bot=0, bc_bot_type='constant', w = -0.002)

# SF6mp stands for SF6 gas in micro pores, it is immobile and only collects SF6;
ftc1.add_species(theta=phi_p, name='SF6mp', D=1e-18, init_C=0, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')

#((phi_g**(10/3))/(phi**2))*
#((phi_w**(10/3))/(phi**2))*

# # Constants
ftc1.constants['k_w_in'] =  0.0005 #from FTR w
ftc1.constants['k_w_out'] = 0.01
#0.4

ftc1.constants['k_g_in'] = 0.9   #0.6
ftc1.constants['k_g_out'] = 150    #70

ftc1.constants['phi_w'] = phi_w
ftc1.constants['phi_g'] = phi_g
ftc1.constants['phi_p'] = phi_p


# # Rates of diffusion into pores and out
ftc1.rates['R_w_in'] = 'k_w_in * SF6w'
ftc1.rates['R_w_out'] = 'k_w_out * SF6mp'

ftc1.rates['R_g_in'] = 'k_g_in * SF6w'
ftc1.rates['R_g_out'] = 'k_g_out * SF6g'

# # dcdt
ftc1.dcdt['SF6w'] = '-R_g_in + R_g_out * phi_g - R_w_in + R_w_out * phi_p'
ftc1.dcdt['SF6g'] = 'R_g_in / phi_g - R_g_out'
ftc1.dcdt['SF6mp'] = 'R_w_in / phi_p - R_w_out'

# %%
Fx = np.zeros(t.size)

# %%
for i in range(0, len(ftc1.time)):
    #if (ftc1.time[i] > 130 and ftc1.time[i] < 302):
    #    ftc1.change_boundary_conditions('SF6g', i,  bc_top=0, bc_top_type='flux')
    #else:
    #    ftc1.change_boundary_conditions('SF6g', i, bc_top=0, bc_top_type='constant')
        #Fx[i] = ftc1.estimate_flux_at_top('SF6g', i)
    if any([ftc1.time[i] == T_inj for T_inj in T1Ti]):
        SF6_add = np.zeros(x.size)
        SF6_add[x > 0] = 0
        

        
        SF6_add[x > 18 - (h_inj/2)] = T1Ci[T1Ti==ftc1.time[i]][0]
        SF6_add[x > 18 + (h_inj/2)] = 0
        
        
                
        new_profile = ftc1.profiles['SF6w'] + SF6_add
        ftc1.change_concentration_profile('SF6w', i, new_profile)

    ftc1.integrate_one_timestep(i)

# %%
#ftc1.profiles['SF6w']

# %%
ftc1.plot_contourplots()

# %%
F1 = ftc1.estimate_flux_at_top('SF6g')
F2 = ftc1.estimate_flux_at_top('SF6w')
# gas flux

plt.plot(ftc1.time, F1)
plt.plot(ftc1.time, F2)
plt.plot(ftc1.time, F2+F1, 'k-.')
# plt.plot(T_frz, [0] )
# F2 = ftc.estimate_flux_at_top('SF6w') # dissolved gas flux
# plt.plot(ftc.time, F2)

#plt.scatter(T1Tm, T1C1h)

plt.scatter((T1Tm[::2]+1), dC3h*Vh3/SA/dT)
#plt.ylim([0.0000,0.00005])
#plt.xlim([-0.0001,300])


#T1Tm[::2]+1
#dC1h*Vh1/SA/dT

#len(ftc1.time)
#for item in ftc1.time:
 #   print (item)

#len(F1)
#for item in F1:
#    print (item)


    
#print (dC1h*Vh1/SA/dT)
#print (T1Tm[::2]+1)

# %%
ftc1.plot_depths( 'SF6w', depths=[9,21,33], time_to_plot=132)

plt.scatter(T1Tm, T1C3D21, color='g')
plt.scatter(T1Tm, T1C3D9, color='b')
plt.scatter(T1Tm, T1C3D33, color='r')
       

ftc1.plot_depths( 'SF6mp', depths=[9,21,33], time_to_plot=132)

plt.scatter(T1Tm, T1C3D21, color='g')
plt.scatter(T1Tm, T1C3D9, color='b')
plt.scatter(T1Tm, T1C3D33, color='r')


ftc1.plot_depths( 'SF6g', depths=[9,21,33], time_to_plot=132)

plt.scatter(T1Tm, T1C3D21, color='g')
plt.scatter(T1Tm, T1C3D9, color='b')
plt.scatter(T1Tm, T1C3D33, color='r')
#plt.xlim([0,300])
#plt.ylim([0,0.0003])

# %%
#ftc1.SF6g.concentration[ftc1.x == 18,:]

# %%
zm = 9
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0] + ftc1.SF6g.concentration[ftc1.x == zm,:][0] + ftc1.SF6mp.concentration[ftc1.x == zm,:][0], label = '9')
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0] + ftc1.SF6mp.concentration[ftc1.x == zm,:][0], label = '9')
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0], label = '9')
#plt.plot(ftc1.time, (ftc1.SF6w.concentration[ftc1.x == zm,:][0]*phi_w[ftc1.x == zm] + ftc1.SF6g.concentration[ftc1.x == zm,:][0]*phi_g[ftc1.x == zm])/(phi_w[ftc1.x == zm]+phi_g[ftc1.x == zm]+phi_p[ftc1.x == zm]), label = '33')
plt.plot(ftc1.time, (ftc1.SF6w.concentration[ftc1.x == zm,:][0]*phi_w[ftc1.x == zm]) / (phi_w[ftc1.x == zm]), label = '9')

zm = 21
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0] + ftc1.SF6g.concentration[ftc1.x == zm,:][0] + ftc1.SF6mp.concentration[ftc1.x == zm,:][0], label = '21')
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0] + ftc1.SF6mp.concentration[ftc1.x == zm,:][0], label = '21')
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0], label = '21')
#plt.plot(ftc1.time, (ftc1.SF6w.concentration[ftc1.x == zm,:][0]*phi_w[ftc1.x == zm] + ftc1.SF6g.concentration[ftc1.x == zm,:][0]*phi_g[ftc1.x == zm])/(phi_w[ftc1.x == zm]+phi_g[ftc1.x == zm]+phi_p[ftc1.x == zm]), label = '33')
plt.plot(ftc1.time, (ftc1.SF6w.concentration[ftc1.x == zm,:][0]*phi_w[ftc1.x == zm]) / (phi_w[ftc1.x == zm]), label = '21')

zm = 33
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0] + ftc1.SF6g.concentration[ftc1.x == zm,:][0] + ftc1.SF6mp.concentration[ftc1.x == zm,:][0], label = '33')
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0] + ftc1.SF6mp.concentration[ftc1.x == zm,:][0], label = '33')
#plt.plot(ftc1.time, ftc1.SF6w.concentration[ftc1.x == zm,:][0], label = '33')
#plt.plot(ftc1.time, (ftc1.SF6w.concentration[ftc1.x == zm,:][0]*phi_w[ftc1.x == zm] + ftc1.SF6g.concentration[ftc1.x == zm,:][0]*phi_g[ftc1.x == zm])/(phi_w[ftc1.x == zm]+phi_g[ftc1.x == zm]+phi_p[ftc1.x == zm]), label = '33')
plt.plot(ftc1.time, (ftc1.SF6w.concentration[ftc1.x == zm,:][0]*phi_w[ftc1.x == zm]) / (phi_w[ftc1.x == zm]), label = '33')


plt.scatter(T1Tm, T1C3D21, color='g', label=21)
plt.scatter(T1Tm, T1C3D9, color='b', label=9)
plt.scatter(T1Tm, T1C3D33, color='r', label=33)
plt.legend()

# %%
#FIRST FREEZE PERIOD#

# %%
prev_g1 = ftc1.profiles.SF6g
prev_w1 = ftc1.profiles.SF6w
prev_p1 = ftc1.profiles.SF6mp

# %%
tend = 145 ## hours

# %%
#Total porosity#

# phi = 0.97

phi = ( 0.99 - 0.91 ) * np.exp( -x / 10 ) + 0.91

#phi = np.array ([0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 
#       0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#       0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94,
#        0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 
#        0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#        0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91,
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95])

#phi

# %%
dT = F1Tm[1::2] - F1Tm[::2]

dC3h = (F1C3h[1::2] - F1C3h[::2])

Mi = F1Ci*Vi # mass injected

#h_inj = Vi/SA/phi
h_inj = Vi/SA/0.93
h_inj
# Out:
# 0.48678214375801243

# %%
ftc2 = Column(L, dx, tend, dt)

# %%
#Pores from the FTR experiment#

phi_w = phi*(0.875/0.97)
phi_g = 1 - phi
#phi_g = phi*((0.97-0.875)/0.97)
#phi_p = 1 - phi
phi_p = phi*((0.97-0.875)/0.97) 

# conversion factor from water to gas
F_wg = phi_w/phi_g
# conversion factor from water to pore space
F_wp = phi_w/phi_p

# %%
ftc2.add_species(theta=(((phi_g**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6g', D= D_SF6g, init_C = prev_g1, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='constant', w = 0.0099)  #-0.055
ftc2.add_species(theta=(((phi_w**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6w', D= D_SF6w, init_C = prev_w1, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='constant', w = 0.0099) #0.13

# SF6mp stands for SF6 gas in micro pores, it is immobile and only collects SF6;
ftc2.add_species(theta=phi_p, name='SF6mp', D=1e-18, init_C = prev_p1, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')

#((phi_g**(10/3))/(phi**2))*
#((phi_w**(10/3))/(phi**2))*

# # Constants
ftc2.constants['k_w_in'] = 0.0   #from FTR w    0.028
ftc2.constants['k_w_out'] = 0.09

ftc2.constants['k_g_in'] = 0.9
ftc2.constants['k_g_out'] = 150

ftc2.constants['phi_w'] = phi_w
ftc2.constants['phi_g'] = phi_g
ftc2.constants['phi_p'] = phi_p


# # Rates of diffusion into pores and out
ftc2.rates['R_w_in'] = 'k_w_in * SF6w'
ftc2.rates['R_w_out'] = 'k_w_out * SF6mp'

ftc2.rates['R_g_in'] = 'k_g_in * SF6w'
ftc2.rates['R_g_out'] = 'k_g_out * SF6g'

# # dcdt
ftc2.dcdt['SF6w'] = '-R_g_in + R_g_out * phi_g - R_w_in + R_w_out * phi_p'
ftc2.dcdt['SF6g'] = 'R_g_in / phi_g - R_g_out'
ftc2.dcdt['SF6mp'] = 'R_w_in / phi_p - R_w_out'

# %%
Fx = np.zeros(t.size)

# %%
for i in range(0, len(ftc2.time)):
    #if (ftc1.time[i] > 130 and ftc1.time[i] < 302):
    #    ftc1.change_boundary_conditions('SF6g', i,  bc_top=0, bc_top_type='flux')
    #else:
    #    ftc1.change_boundary_conditions('SF6g', i, bc_top=0, bc_top_type='constant')
        #Fx[i] = ftc1.estimate_flux_at_top('SF6g', i)
    if any([ftc2.time[i] == T_inj for T_inj in F1Ti]):
        SF6_add = np.zeros(x.size)
        SF6_add[x > 0] = 0
        

        
        SF6_add[x > 18 - (h_inj)/2] = F1Ci[F1Ti==ftc2.time[i]][0]
        SF6_add[x > 18 + (h_inj)/2] = 0
        
        
                
        new_profile = ftc2.profiles['SF6w'] + SF6_add
        ftc2.change_concentration_profile('SF6w', i, new_profile)

    ftc2.integrate_one_timestep(i)

# %%
ftc2.plot_contourplots()

# %%
F1 = ftc2.estimate_flux_at_top('SF6g')
F2 = ftc2.estimate_flux_at_top('SF6w')
# gas flux

plt.plot(ftc2.time, F1)
plt.plot(ftc2.time, F2)
plt.plot(ftc2.time, F2+F1, 'k-.')
# plt.plot(T_frz, [0] )
# F2 = ftc.estimate_flux_at_top('SF6w') # dissolved gas flux
# plt.plot(ftc.time, F2)

#plt.scatter(T1Tm, T1C1h)

plt.scatter((F1Tm[::2]+1), dC3h*Vh3/SA/dT)
#plt.ylim([0.00004,0.00005])
#plt.xlim([-0.0001,300])


#T1Tm[::2]+1
#dC1h*Vh1/SA/dT

#len(ftc1.time)
#for item in ftc1.time:
 #   print (item)

#len(F1)
#for item in F1:
#    print (item)


    
#print (dC1h*Vh1/SA/dT)
#print (T1Tm[::2]+1)

# %%
ftc2.plot_depths( 'SF6w', depths=[9,21,33], time_to_plot=145)

plt.scatter(F1Tm, F1C3D21, color='g')
#plt.scatter(F1Tm, F1C3D9, color='b')
plt.scatter(F1Tm, F1C3D33, color='r')
       

ftc2.plot_depths( 'SF6mp', depths=[9,21,33], time_to_plot=145)

plt.scatter(F1Tm, F1C3D21, color='g')
#plt.scatter(F1Tm, F1C3D9, color='b')
plt.scatter(F1Tm, F1C3D33, color='r')


ftc2.plot_depths( 'SF6g', depths=[9,21,33], time_to_plot=145)

plt.scatter(F1Tm, F1C3D21, color='g')
#plt.scatter(F1Tm, F1C3D9, color='b')
plt.scatter(F1Tm, F1C3D33, color='r')
#plt.xlim([0,300])
#plt.ylim([0,0.0003])

# %%
zm = 9
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '9')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '9')
plt.plot(ftc2.time, (ftc2.SF6w.concentration[ftc2.x == zm,:][0]*phi_w[ftc2.x == zm]) / (phi_w[ftc2.x == zm]), label = '9')


zm = 21
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '21')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '21')
plt.plot(ftc2.time, (ftc2.SF6w.concentration[ftc2.x == zm,:][0]*phi_w[ftc2.x == zm]) / (phi_w[ftc2.x == zm]), label = '21')



zm = 33
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '33')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '33')
plt.plot(ftc2.time, (ftc2.SF6w.concentration[ftc2.x == zm,:][0]*phi_w[ftc2.x == zm]) / (phi_w[ftc2.x == zm]), label = '33')



plt.scatter(F1Tm, F1C3D21, color='g', label=21)
#plt.scatter(F1Tm, F1C3D9, color='b', label=9)
plt.scatter(F1Tm, F1C3D33, color='r', label=33)
plt.legend()

# %%
#SECOND THAW PERIOD#

# %%
prev_g2 = ftc2.profiles.SF6g
prev_w2 = ftc2.profiles.SF6w
prev_p2 = ftc2.profiles.SF6mp

# %%
tend = 123 ## hours

# %%
#Total porosity#

# phi = 0.97

phi = ( 0.99 - 0.91 ) * np.exp( -x / 10 ) + 0.91

#phi = np.array ([0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 
#       0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#       0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94,
#        0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 
#        0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#        0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91,
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95])

#phi

# %%
dT = T2Tm[1::2] - T2Tm[::2]

dC3h = (T2C3h[1::2] - T2C3h[::2])

Mi = T2Ci*Vi # mass injected

#h_inj = Vi/SA/phi
h_inj = Vi/SA/0.93
h_inj
# Out:
# 0.48678214375801243

# %%
ftc3 = Column(L, dx, tend, dt)

# %%
#Pores from the FTR experiment#

phi_w = phi*(0.93/0.97)
phi_g = 1 - phi
#phi_g = phi*((0.97-0.875)/0.97)
#phi_p = 1 - phi
phi_p = phi*((0.97-0.93)/0.97) 

# conversion factor from water to gas
F_wg = phi_w/phi_g
# conversion factor from water to pore space
F_wp = phi_w/phi_p

# %%
ftc3.add_species(theta=((((phi_g**(10/3))/(phi**2))) / (phi_w + phi_g)), name='SF6g', D= D_SF6g, init_C = prev_g2, bc_top=0, bc_top_type='constant', bc_bot=0, bc_bot_type='constant', w = -0.00)  #-0.055
ftc3.add_species(theta=(((phi_w**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6w', D= D_SF6w, init_C = prev_w2, bc_top=0, bc_top_type='constant', bc_bot=0, bc_bot_type='constant', w = -0.002) #0.13

# SF6mp stands for SF6 gas in micro pores, it is immobile and only collects SF6;
ftc3.add_species(theta=phi_p, name='SF6mp', D=1e-18, init_C = prev_p2, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')

#((phi_g**(10/3))/(phi**2))*
#((phi_w**(10/3))/(phi**2))*

# # Constants
ftc3.constants['k_w_in'] = 0.01   #from FTR w    #0.06
ftc3.constants['k_w_out'] = 0.03                  #0.02

ftc3.constants['k_g_in'] = 0.95  #0.019            #0.9
ftc3.constants['k_g_out'] = 90                #90



ftc3.constants['phi_w'] = phi_w
ftc3.constants['phi_g'] = phi_g
ftc3.constants['phi_p'] = phi_p


# # Rates of diffusion into pores and out
ftc3.rates['R_w_in'] = 'k_w_in * SF6w'
ftc3.rates['R_w_out'] = 'k_w_out * SF6mp'

ftc3.rates['R_g_in'] = 'k_g_in * SF6w'
ftc3.rates['R_g_out'] = 'k_g_out * SF6g'

# # dcdt
ftc3.dcdt['SF6w'] = '-R_g_in + R_g_out * phi_g - R_w_in + R_w_out * phi_p'
ftc3.dcdt['SF6g'] = 'R_g_in / phi_g - R_g_out'
ftc3.dcdt['SF6mp'] = 'R_w_in / phi_p - R_w_out'

# %%
Fx = np.zeros(t.size)

# %%
for i in range(0, len(ftc3.time)):
    #if (ftc1.time[i] > 130 and ftc1.time[i] < 302):
    #    ftc1.change_boundary_conditions('SF6g', i,  bc_top=0, bc_top_type='flux')
    #else:
    #    ftc1.change_boundary_conditions('SF6g', i, bc_top=0, bc_top_type='constant')
        #Fx[i] = ftc1.estimate_flux_at_top('SF6g', i)
    if any([ftc3.time[i] == T_inj for T_inj in T2Ti]):
        SF6_add = np.zeros(x.size)
        SF6_add[x > 0] = 0
        

        
        SF6_add[x > 18 - (h_inj)/2] = T2Ci[T2Ti==ftc3.time[i]][0]
        SF6_add[x > 18 + (h_inj)/2] = 0
        
        
                
        new_profile = ftc3.profiles['SF6w'] + SF6_add
        ftc3.change_concentration_profile('SF6w', i, new_profile)

    ftc3.integrate_one_timestep(i)

# %%
ftc3.plot_contourplots()

# %%
F1 = ftc3.estimate_flux_at_top('SF6g')
F2 = ftc3.estimate_flux_at_top('SF6w')
# gas flux

plt.plot(ftc3.time, F1)
plt.plot(ftc3.time, F2)
plt.plot(ftc3.time, F2+F1, 'k-.')
# plt.plot(T_frz, [0] )
# F2 = ftc.estimate_flux_at_top('SF6w') # dissolved gas flux
# plt.plot(ftc.time, F2)

#plt.scatter(T1Tm, T1C1h)

plt.scatter((T2Tm[::2]+1), dC3h*Vh3/SA/dT)
#plt.ylim([0.00004,0.00025])
#plt.xlim([-0.0001,30])


#T1Tm[::2]+1
#dC1h*Vh1/SA/dT

#len(ftc1.time)
#for item in ftc1.time:
 #   print (item)

#len(F1)
#for item in F1:
#    print (item)


    
#print (dC1h*Vh1/SA/dT)
#print (T1Tm[::2]+1)

# %%
ftc3.plot_depths( 'SF6w', depths=[9,21,33], time_to_plot=123)

plt.scatter(T2Tm, T2C3D21, color='g')
plt.scatter(T2Tm, T2C3D9, color='b')
plt.scatter(T2Tm, T2C3D33, color='r')
       

ftc3.plot_depths( 'SF6mp', depths=[9,21,33], time_to_plot=123)

plt.scatter(T2Tm, T2C3D21, color='g')
plt.scatter(T2Tm, T2C3D9, color='b')
plt.scatter(T2Tm, T2C3D33, color='r')


ftc3.plot_depths( 'SF6g', depths=[9,21,33], time_to_plot=123)

plt.scatter(T2Tm, T2C3D21, color='g')
plt.scatter(T2Tm, T2C3D9, color='b')
plt.scatter(T2Tm, T2C3D33, color='r')
#plt.xlim([0,300])
#plt.ylim([0,0.0003])

# %%
zm = 9
#plt.plot(ftc3.time, ftc3.SF6w.concentration[ftc3.x == zm,:][0] + ftc3.SF6g.concentration[ftc3.x == zm,:][0] + ftc3.SF6mp.concentration[ftc3.x == zm,:][0], label = '9')
#plt.plot(ftc3.time, ftc3.SF6w.concentration[ftc3.x == zm,:][0] + ftc3.SF6mp.concentration[ftc3.x == zm,:][0], label = '9')
plt.plot(ftc3.time, (ftc3.SF6w.concentration[ftc3.x == zm,:][0]*phi_w[ftc3.x == zm]) / (phi_w[ftc3.x == zm]), label = '9')



zm = 21
#plt.plot(ftc3.time, ftc3.SF6w.concentration[ftc3.x == zm,:][0] + ftc3.SF6g.concentration[ftc3.x == zm,:][0] + ftc3.SF6mp.concentration[ftc3.x == zm:][0], label = '21')
#plt.plot(ftc3.time, ftc3.SF6w.concentration[ftc3.x == zm,:][0] + ftc3.SF6mp.concentration[ftc3.x == zm,:][0], label = '21')
plt.plot(ftc3.time, (ftc3.SF6w.concentration[ftc3.x == zm,:][0]*phi_w[ftc3.x == zm]) / (phi_w[ftc3.x == zm]), label = '21')



zm = 33
#plt.plot(ftc3.time, ftc3.SF6w.concentration[ftc3.x == zm,:][0] + ftc3.SF6g.concentration[ftc3.x == zm,:][0] + ftc3.SF6mp.concentration[ftc3.x == zm,:][0], label = '33')
#plt.plot(ftc3.time, ftc3.SF6w.concentration[ftc3.x == zm,:][0] + ftc3.SF6mp.concentration[ftc3.x == zm,:][0], label = '33')
plt.plot(ftc3.time, (ftc3.SF6w.concentration[ftc3.x == zm,:][0]*phi_w[ftc3.x == zm]) / (phi_w[ftc3.x == zm]), label = '33')



plt.scatter(T2Tm, T2C3D21, color='g', label=21)
plt.scatter(T2Tm, T2C3D9, color='b', label=9)
plt.scatter(T2Tm, T2C3D33, color='r', label=33)
plt.legend()

# %%
#SECOND FREEZE PERIOD#

# %%
prev_g3 = ftc3.profiles.SF6g
prev_w3 = ftc3.profiles.SF6w
prev_p3 = ftc3.profiles.SF6mp

# %%
tend = 98 ## hours

# %%
#Total porosity#

# phi = 0.97

phi = ( 0.99 - 0.91 ) * np.exp( -x / 10 ) + 0.91

#phi = np.array ([0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 
#       0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#       0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94,
#        0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 
#        0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#        0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91,
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95])

#phi

# %%
dT = F2Tm[1::2] - F2Tm[::2]

dC3h = (F2C3h[1::2] - F2C3h[::2])

Mi = F2Ci*Vi # mass injected

#h_inj = Vi/SA/phi
h_inj = Vi/SA/0.93
h_inj
# Out:
# 0.48678214375801243

# %%
ftc4 = Column(L, dx, tend, dt)

# %%
#Pores from the FTR experiment#

phi_w = phi*(0.875/0.97)
phi_g = 1 - phi
#phi_g = phi*((0.97-0.875)/0.97)
#phi_p = 1 - phi
phi_p = phi*((0.97-0.875)/0.97) 

# conversion factor from water to gas
F_wg = phi_w/phi_g
# conversion factor from water to pore space
F_wp = phi_w/phi_p

# %%
ftc4.add_species(theta=(((phi_g**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6g', D= D_SF6g, init_C = prev_g3, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='constant', w = 0.0093)  #-0.055
ftc4.add_species(theta=(((phi_w**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6w', D= D_SF6w, init_C = prev_w3, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='constant', w = 0.0093) #0.13

# SF6mp stands for SF6 gas in micro pores, it is immobile and only collects SF6;
ftc4.add_species(theta=phi_p, name='SF6mp', D=1e-18, init_C = prev_p3, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')

#((phi_g**(10/3))/(phi**2))*
#((phi_w**(10/3))/(phi**2))*

# # Constants
ftc4.constants['k_w_in'] = 0.03  #from FTR w    0.028
ftc4.constants['k_w_out'] = 0.3

ftc4.constants['k_g_in'] = 0.9
ftc4.constants['k_g_out'] = 90

ftc4.constants['phi_w'] = phi_w
ftc4.constants['phi_g'] = phi_g
ftc4.constants['phi_p'] = phi_p


# # Rates of diffusion into pores and out
ftc4.rates['R_w_in'] = 'k_w_in * SF6w'
ftc4.rates['R_w_out'] = 'k_w_out * SF6mp'

ftc4.rates['R_g_in'] = 'k_g_in * SF6w'
ftc4.rates['R_g_out'] = 'k_g_out * SF6g'

# # dcdt
ftc4.dcdt['SF6w'] = '-R_g_in + R_g_out * phi_g - R_w_in + R_w_out * phi_p'
ftc4.dcdt['SF6g'] = 'R_g_in / phi_g - R_g_out'
ftc4.dcdt['SF6mp'] = 'R_w_in / phi_p - R_w_out'

# %%
Fx = np.zeros(t.size)

# %%
for i in range(0, len(ftc4.time)):
    #if (ftc1.time[i] > 130 and ftc1.time[i] < 302):
    #    ftc1.change_boundary_conditions('SF6g', i,  bc_top=0, bc_top_type='flux')
    #else:
    #    ftc1.change_boundary_conditions('SF6g', i, bc_top=0, bc_top_type='constant')
        #Fx[i] = ftc1.estimate_flux_at_top('SF6g', i)
    if any([ftc4.time[i] == T_inj for T_inj in F2Ti]):
        SF6_add = np.zeros(x.size)
        SF6_add[x > 0] = 0
        

        
        SF6_add[x > 18 - (h_inj)/2] = F2Ci[F2Ti==ftc4.time[i]][0]
        SF6_add[x > 18 + (h_inj)/2] = 0
        
        
                
        new_profile = ftc4.profiles['SF6w'] + SF6_add
        ftc4.change_concentration_profile('SF6w', i, new_profile)

    ftc4.integrate_one_timestep(i)

# %%
ftc4.plot_contourplots()

# %%
F1 = ftc4.estimate_flux_at_top('SF6g')
F2 = ftc4.estimate_flux_at_top('SF6w')
# gas flux

plt.plot(ftc4.time, F1)
plt.plot(ftc4.time, F2)
plt.plot(ftc4.time, F2+F1, 'k-.')
# plt.plot(T_frz, [0] )
# F2 = ftc.estimate_flux_at_top('SF6w') # dissolved gas flux
# plt.plot(ftc.time, F2)

#plt.scatter(T1Tm, T1C1h)

plt.scatter((F2Tm[::2]+1), dC3h*Vh3/SA/dT)
#plt.ylim([0.00004,0.00005])
#plt.xlim([-0.0001,300])


#T1Tm[::2]+1
#dC1h*Vh1/SA/dT

#len(ftc1.time)
#for item in ftc1.time:
 #   print (item)

#len(F1)
#for item in F1:
#    print (item)


    
#print (dC1h*Vh1/SA/dT)
#print (T1Tm[::2]+1)

# %%
ftc4.plot_depths( 'SF6w', depths=[9,21,33], time_to_plot=98)

plt.scatter(F2Tm, F2C3D21, color='g')
#plt.scatter(F2Tm, F2C3D9, color='b')
plt.scatter(F2Tm, F2C3D33, color='r')
       

ftc4.plot_depths( 'SF6mp', depths=[9,21,33], time_to_plot=98)

plt.scatter(F2Tm, F2C3D21, color='g')
#plt.scatter(F2Tm, F2C3D9, color='b')
plt.scatter(F2Tm, F2C3D33, color='r')


ftc4.plot_depths( 'SF6g', depths=[9,21,33], time_to_plot=98)

plt.scatter(F2Tm, F2C3D21, color='g')
#plt.scatter(F2Tm, F2C3D9, color='b')
plt.scatter(F2Tm, F2C3D33, color='r')
#plt.xlim([0,300])
#plt.ylim([0,0.0003])

# %%
zm = 9
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '9')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '9')
plt.plot(ftc4.time, (ftc4.SF6w.concentration[ftc4.x == zm,:][0]*phi_w[ftc4.x == zm]) / (phi_w[ftc4.x == zm]), label = '9')


zm = 21
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '21')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '21')
plt.plot(ftc4.time, (ftc4.SF6w.concentration[ftc4.x == zm,:][0]*phi_w[ftc4.x == zm]) / (phi_w[ftc4.x == zm]), label = '21')



zm = 33
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '33')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '33')
plt.plot(ftc4.time, (ftc4.SF6w.concentration[ftc4.x == zm,:][0]*phi_w[ftc4.x == zm]) / (phi_w[ftc4.x == zm]), label = '33')



plt.scatter(F2Tm, F2C3D21, color='g', label=21)
#plt.scatter(F1Tm, F1C3D9, color='b', label=9)
plt.scatter(F2Tm, F2C3D33, color='r', label=33)
plt.legend()

# %%
#THIRD THAW PERIOD#

# %%
prev_g4 = ftc4.profiles.SF6g
prev_w4 = ftc4.profiles.SF6w
prev_p4 = ftc4.profiles.SF6mp

# %%
tend = 128 ## hours

# %%
#Total porosity#

# phi = 0.97

phi = ( 0.99 - 0.91 ) * np.exp( -x / 10 ) + 0.91

#phi = np.array ([0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 
#       0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#       0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94,
#        0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 
#        0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#        0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91,
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95])

#phi

# %%
dT = T3Tm[1::2] - T3Tm[::2]

dC3h = (T3C3h[1::2] - T3C3h[::2])

Mi = T3Ci*Vi # mass injected

#h_inj = Vi/SA/phi
h_inj = Vi/SA/0.93
h_inj
# Out:
# 0.48678214375801243

# %%
ftc5 = Column(L, dx, tend, dt)

# %%
#Pores from the FTR experiment#

phi_w = phi*(0.875/0.97)
phi_g = 1 - phi
#phi_g = phi*((0.97-0.875)/0.97)
#phi_p = 1 - phi
phi_p = phi*((0.97-0.875)/0.97) 

# conversion factor from water to gas
F_wg = phi_w/phi_g
# conversion factor from water to pore space
F_wp = phi_w/phi_p

# %%
ftc5.add_species(theta=(((phi_g**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6g', D= D_SF6g, init_C = prev_g4, bc_top=0, bc_top_type='constant', bc_bot=0, bc_bot_type='constant', w = 0.0)  #-0.055
ftc5.add_species(theta=(((phi_w**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6w', D= D_SF6w, init_C = prev_w4, bc_top=0, bc_top_type='constant', bc_bot=0, bc_bot_type='constant', w = 0.002) #0.13

# SF6mp stands for SF6 gas in micro pores, it is immobile and only collects SF6;
ftc5.add_species(theta=phi_p, name='SF6mp', D=1e-18, init_C = prev_p4, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')

#((phi_g**(10/3))/(phi**2))*
#((phi_w**(10/3))/(phi**2))*

# # Constants
ftc5.constants['k_w_in'] = 0.02  #from FTR w    0.06/0.05/0.9/90
ftc5.constants['k_w_out'] = 0.03

ftc5.constants['k_g_in'] = 0.9
ftc5.constants['k_g_out'] = 90

ftc5.constants['phi_w'] = phi_w
ftc5.constants['phi_g'] = phi_g
ftc5.constants['phi_p'] = phi_p


# # Rates of diffusion into pores and out
ftc5.rates['R_w_in'] = 'k_w_in * SF6w'
ftc5.rates['R_w_out'] = 'k_w_out * SF6mp'

ftc5.rates['R_g_in'] = 'k_g_in * SF6w'
ftc5.rates['R_g_out'] = 'k_g_out * SF6g'

# # dcdt
ftc5.dcdt['SF6w'] = '-R_g_in + R_g_out * phi_g - R_w_in + R_w_out * phi_p'
ftc5.dcdt['SF6g'] = 'R_g_in / phi_g - R_g_out'
ftc5.dcdt['SF6mp'] = 'R_w_in / phi_p - R_w_out'

# %%
Fx = np.zeros(t.size)

# %%
for i in range(0, len(ftc5.time)):
    #if (ftc1.time[i] > 130 and ftc1.time[i] < 302):
    #    ftc1.change_boundary_conditions('SF6g', i,  bc_top=0, bc_top_type='flux')
    #else:
    #    ftc1.change_boundary_conditions('SF6g', i, bc_top=0, bc_top_type='constant')
        #Fx[i] = ftc1.estimate_flux_at_top('SF6g', i)
    if any([ftc5.time[i] == T_inj for T_inj in T3Ti]):
        SF6_add = np.zeros(x.size)
        SF6_add[x > 0] = 0
        

        
        SF6_add[x > 18 - (h_inj)/2] = T3Ci[T3Ti==ftc5.time[i]][0]
        SF6_add[x > 18 + (h_inj)/2] = 0
        
        
                
        new_profile = ftc5.profiles['SF6w'] + SF6_add
        ftc5.change_concentration_profile('SF6w', i, new_profile)

    ftc5.integrate_one_timestep(i)

# %%
ftc5.plot_contourplots()

# %%
F1 = ftc5.estimate_flux_at_top('SF6g')
F2 = ftc5.estimate_flux_at_top('SF6w')
# gas flux

plt.plot(ftc5.time, F1)
plt.plot(ftc5.time, F2)
plt.plot(ftc5.time, F2+F1, 'k-.')
# plt.plot(T_frz, [0] )
# F2 = ftc.estimate_flux_at_top('SF6w') # dissolved gas flux
# plt.plot(ftc.time, F2)

#plt.scatter(T1Tm, T1C1h)

plt.scatter((T3Tm[::2]+1), dC3h*Vh3/SA/dT)
#plt.ylim([0.00004,0.00005])
#plt.xlim([-0.0001,300])


#T1Tm[::2]+1
#dC1h*Vh1/SA/dT

#len(ftc1.time)
#for item in ftc1.time:
 #   print (item)

#len(F1)
#for item in F1:
#    print (item)


    
#print (dC1h*Vh1/SA/dT)
#print (T1Tm[::2]+1)

# %%
ftc5.plot_depths( 'SF6w', depths=[9,21,33], time_to_plot=128)

plt.scatter(T3Tm, T3C3D21, color='g')
plt.scatter(T3Tm, T3C3D9, color='b')
plt.scatter(T3Tm, T3C3D33, color='r')
       

ftc5.plot_depths( 'SF6mp', depths=[9,21,33], time_to_plot=128)

plt.scatter(T3Tm, T3C3D21, color='g')
plt.scatter(T3Tm, T3C3D9, color='b')
plt.scatter(T3Tm, T3C3D33, color='r')


ftc5.plot_depths( 'SF6g', depths=[9,21,33], time_to_plot=128)

plt.scatter(T3Tm, T3C3D21, color='g')
plt.scatter(T3Tm, T3C3D9, color='b')
plt.scatter(T3Tm, T3C3D33, color='r')
#plt.xlim([0,300])
#plt.ylim([0,0.0003])

# %%
zm = 9
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '9')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '9')
plt.plot(ftc5.time, (ftc5.SF6w.concentration[ftc5.x == zm,:][0]*phi_w[ftc5.x == zm]) / (phi_w[ftc5.x == zm]), label = '9')


zm = 21
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '21')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '21')
plt.plot(ftc5.time, (ftc5.SF6w.concentration[ftc5.x == zm,:][0]*phi_w[ftc5.x == zm]) / (phi_w[ftc5.x == zm]), label = '21')



zm = 33
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '33')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '33')
plt.plot(ftc5.time, (ftc5.SF6w.concentration[ftc5.x == zm,:][0]*phi_w[ftc5.x == zm]) / (phi_w[ftc5.x == zm]), label = '33')



plt.scatter(T3Tm, T3C3D21, color='g', label=21)
plt.scatter(T3Tm, T3C3D9, color='b', label=9)
plt.scatter(T3Tm, T3C3D33, color='r', label=33)
plt.legend()

# %%
#THIRD FREEZE PERIOD#

# %%
prev_g5 = ftc5.profiles.SF6g
prev_w5 = ftc5.profiles.SF6w
prev_p5 = ftc5.profiles.SF6mp

# %%
tend = 105 ## hours

# %%
#Total porosity#

# phi = 0.97

phi = ( 0.99 - 0.91 ) * np.exp( -x / 10 ) + 0.91

#phi = np.array ([0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 0.96, 
#       0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#       0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94, 0.94,
#        0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 
#        0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95,
#        0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91,
#        0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95, 0.95])

#phi

# %%
dT = F3Tm[1::2] - F3Tm[::2]

dC3h = (F3C3h[1::2] - F3C3h[::2])

Mi = F3Ci*Vi # mass injected

#h_inj = Vi/SA/phi
h_inj = Vi/SA/0.93
h_inj
# Out:
# 0.48678214375801243

# %%
ftc6 = Column(L, dx, tend, dt)

# %%
#Pores from the FTR experiment#

phi_w = phi*(0.875/0.97)
phi_g = 1 - phi
#phi_g = phi*((0.97-0.875)/0.97)
#phi_p = 1 - phi
phi_p = phi*((0.97-0.875)/0.97) 

# conversion factor from water to gas
F_wg = phi_w/phi_g
# conversion factor from water to pore space
F_wp = phi_w/phi_p

# %%
ftc6.add_species(theta=(((phi_g**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6g', D= D_SF6g, init_C = prev_g5, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='constant', w = 0.00)  #-0.055
ftc6.add_species(theta=(((phi_w**(10/3))/(phi**2)) / (phi_w + phi_g)), name='SF6w', D= D_SF6w, init_C = prev_w5, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='constant', w = 0.00) #0.13

# SF6mp stands for SF6 gas in micro pores, it is immobile and only collects SF6;
ftc6.add_species(theta=phi_p, name='SF6mp', D=1e-18, init_C = prev_p5, bc_top=0, bc_top_type='flux', bc_bot=0, bc_bot_type='flux')

#((phi_g**(10/3))/(phi**2))*
#((phi_w**(10/3))/(phi**2))*

# # Constants
ftc6.constants['k_w_in'] = 0.0  #from FTR w    0.028
ftc6.constants['k_w_out'] = 0.9

ftc6.constants['k_g_in'] = 0
ftc6.constants['k_g_out'] = 0.1

ftc6.constants['phi_w'] = phi_w
ftc6.constants['phi_g'] = phi_g
ftc6.constants['phi_p'] = phi_p


# # Rates of diffusion into pores and out
ftc6.rates['R_w_in'] = 'k_w_in * SF6w'
ftc6.rates['R_w_out'] = 'k_w_out * SF6mp'

ftc6.rates['R_g_in'] = 'k_g_in * SF6w'
ftc6.rates['R_g_out'] = 'k_g_out * SF6g'

# # dcdt
ftc6.dcdt['SF6w'] = '-R_g_in + R_g_out * phi_g - R_w_in + R_w_out * phi_p'
ftc6.dcdt['SF6g'] = 'R_g_in / phi_g - R_g_out'
ftc6.dcdt['SF6mp'] = 'R_w_in / phi_p - R_w_out'

# %%
Fx = np.zeros(t.size)

# %%
for i in range(0, len(ftc6.time)):
    #if (ftc1.time[i] > 130 and ftc1.time[i] < 302):
    #    ftc1.change_boundary_conditions('SF6g', i,  bc_top=0, bc_top_type='flux')
    #else:
    #    ftc1.change_boundary_conditions('SF6g', i, bc_top=0, bc_top_type='constant')
        #Fx[i] = ftc1.estimate_flux_at_top('SF6g', i)
    if any([ftc6.time[i] == T_inj for T_inj in F3Ti]):
        SF6_add = np.zeros(x.size)
        SF6_add[x > 0] = 0
        

        
        SF6_add[x > 18 - (h_inj)/2] = F3Ci[F3Ti==ftc6.time[i]][0]
        SF6_add[x > 18 + (h_inj)/2] = 0
        
        
                
        new_profile = ftc6.profiles['SF6w'] + SF6_add
        ftc6.change_concentration_profile('SF6w', i, new_profile)

    ftc6.integrate_one_timestep(i)

# %%
ftc6.plot_contourplots()

# %%
F1 = ftc6.estimate_flux_at_top('SF6g')
F2 = ftc6.estimate_flux_at_top('SF6w')
# gas flux

plt.plot(ftc6.time, F1)
plt.plot(ftc6.time, F2)
plt.plot(ftc6.time, F2+F1, 'k-.')
# plt.plot(T_frz, [0] )
# F2 = ftc.estimate_flux_at_top('SF6w') # dissolved gas flux
# plt.plot(ftc.time, F2)

#plt.scatter(T1Tm, T1C1h)

plt.scatter((F3Tm[::2]+1), dC3h*Vh3/SA/dT)
#plt.ylim([0.00004,0.00005])
#plt.xlim([-0.0001,300])


#T1Tm[::2]+1
#dC1h*Vh1/SA/dT

#len(ftc1.time)
#for item in ftc1.time:
 #   print (item)

#len(F1)
#for item in F1:
#    print (item)


    
#print (dC1h*Vh1/SA/dT)
#print (T1Tm[::2]+1)

# %%
ftc6.plot_depths( 'SF6w', depths=[9,21,33], time_to_plot=105)

plt.scatter(F3Tm, F3C3D21, color='g')
#plt.scatter(F3Tm, F3C3D9, color='b')
plt.scatter(F3Tm, F3C3D33, color='r')
       

ftc6.plot_depths( 'SF6mp', depths=[9,21,33], time_to_plot=105)

plt.scatter(F3Tm, F3C3D21, color='g')
#plt.scatter(F3Tm, F3C3D9, color='b')
plt.scatter(F3Tm, F3C3D33, color='r')


ftc6.plot_depths( 'SF6g', depths=[9,21,33], time_to_plot=105)

plt.scatter(F3Tm, F3C3D21, color='g')
#plt.scatter(F3Tm, F3C3D9, color='b')
plt.scatter(F3Tm, F3C3D33, color='r')
#plt.xlim([0,300])
#plt.ylim([0,0.0003])

# %%
zm = 9
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '9')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '9')
plt.plot(ftc6.time, (ftc6.SF6w.concentration[ftc6.x == zm,:][0]*phi_w[ftc6.x == zm]) / (phi_w[ftc6.x == zm]), label = '9')


zm = 21
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '21')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '21')
plt.plot(ftc6.time, (ftc6.SF6w.concentration[ftc6.x == zm,:][0]*phi_w[ftc6.x == zm]) / (phi_w[ftc6.x == zm]), label = '21')



zm = 33
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0] + ftc2.SF6mp.concentration[ftc2.x == zm,:][0], label = '33')
#plt.plot(ftc2.time, ftc2.SF6w.concentration[ftc2.x == zm,:][0] + ftc2.SF6g.concentration[ftc2.x == zm,:][0], label = '33')
plt.plot(ftc6.time, (ftc6.SF6w.concentration[ftc6.x == zm,:][0]*phi_w[ftc6.x == zm]) / (phi_w[ftc6.x == zm]), label = '33')



plt.scatter(F3Tm, F3C3D21, color='g', label=21)
#plt.scatter(F3Tm, F3C3D9, color='b', label=9)
plt.scatter(F3Tm, F3C3D33, color='r', label=33)
plt.legend()
