# %%
# %run danny_optimization.py
# Out:
# /Users/imarkelo/git/PorousMediaLab/examples/test/danny_optimization.py:35: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   x = np.linspace(0, L, L / dx + 1)
# /Users/imarkelo/git/PorousMediaLab/examples/test/danny_optimization.py:36: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   t = np.linspace(0, tend, round(tend / dt) + 1)
# -0.00948625691731 0.119755015154 0.0149131464507 0.476168401299 115.165761587
# 0.00454060074556
# -0.00996056976318 0.119755015154 0.0149131464507 0.476168401299 115.165761587
# 0.00453973531596
# -0.00948625691731 0.125742765912 0.0149131464507 0.476168401299 115.165761587
# 0.0046096752875
# -0.00948625691731 0.119755015154 0.0156588037732 0.476168401299 115.165761587
# 0.0045047836039
# -0.00948625691731 0.119755015154 0.0149131464507 0.499976821364 115.165761587
# 0.00451106818121
# ...

# %%
round(11/10)
# Out:
# 1

# %%
round(11/10)
